# %% [markdown]
# # VacationPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os
import json

# Import API key
from api_keys import g_key

# %% [markdown]
# ### Store Part I results into DataFrame
# * Load the csv exported in Part I to a DataFrame

# %%
city_data = pd.read_csv("../output_data/cities.csv")
city_data.head(20)
# Out:
#     City_ID               City  Cloudiness Country        Date  Humidity  \
# 0         0          ostrovnoy           2      RU  1558378754        72
# 1         1          mahebourg          75      MU  1558378503        74
# 2         2            qaanaaq          25      GL  1558378755        73
# 3         3             zhuhai           0      CN  1558378755        39
# 4         4          cape town          20      ZA  1558378755        76
# 5         5             atuona          78      PF  1558378755        76
# 6         6           flinders           0      AU  1558378755        62
# 7         7              opuwo           0     NaN  1558378523        23
# 8         8              tiksi          95      RU  1558378756        88
# 9         9  pushkinskiye gory           6      RU  1558378756        70
# 10       10             aykhal          90      RU  1558378756        48
# 11       11             castro           0      CL  1558378756        70
# ...

# %% [markdown]
# ### Humidity Heatmap
# * Configure gmaps.
# * Use the Lat and Lng as locations and Humidity as the weight.
# * Add Heatmap layer to map.

# %%
gmaps.configure(api_key=g_key)
city_data = city_data.dropna()

locs = city_data[["Lat", "Lng"]].astype(float)

hums = city_data["Humidity"].astype(float)

# %%
fig = gmaps.figure()

heat_layer = gmaps.heatmap_layer(locs, weights=hums, 
                                 dissipating=False, max_intensity=100,
                                 point_radius = 2)

fig.add_layer(heat_layer)

fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# ### Create new DataFrame fitting weather criteria
# * Narrow down the cities to fit weather conditions.
# * Drop any rows will null values.

# %%
no_cloud_data = city_data

no_cloud_data = no_cloud_data.loc[no_cloud_data["Cloudiness"] == 0]

no_cloud_data = no_cloud_data.loc[(no_cloud_data["Max Temp"] < 80) & (no_cloud_data["Max Temp"] > 70)]

no_cloud_data = no_cloud_data.loc[no_cloud_data["Wind Speed"] < 10]


no_cloud_data
# Out:
#      City_ID          City  Cloudiness Country        Date  Humidity    Lat  \
# 70        70  ponta do sol           0      BR  1558378767        57 -20.63
# 88        88      cidreira           0      BR  1558378770        66 -30.17
# 138      138     morondava           0      MG  1558378780        69 -20.30
# 139      139         vaini           0      IN  1558378780        88  15.34
# 176      176         nador           0      MA  1558378499        40  35.17
# 297      297         mogok           0      MM  1558378844        51  22.92
# 444      444       birjand           0      IR  1558378880        26  32.86
#
#        Lng  Max Temp  Wind Speed
# 70  -46.00     73.68        5.32
# 88  -50.22     76.56        5.50
# 138  44.28     79.08        9.06
# 139  74.49     78.90        1.59
# 176  -2.93     75.20        6.93
# 297  96.51     72.24        2.77
# 444  59.22     71.60        9.17

# %% [markdown]
# ### Hotel Map
# * Store into variable named `hotel_df`.
# * Add a "Hotel Name" column to the DataFrame.
# * Set parameters to search for hotels with 5000 meters.
# * Hit the Google Places API for each city's coordinates.
# * Store the first Hotel result into the DataFrame.
# * Plot markers on top of the heatmap.

# %%
hotel_df = no_cloud_data

for index, row in hotel_df.iterrows():
    
    lat = row["Lat"]
    lng = row["Lng"]
    
    location = f"{lat},{lng}"
    
    params = {"location": location,
              "radius":5000,
              "types": "lodging",
              "key": g_key}
    
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
     
    print(f"The Closest Hotel for Index {index}: {row['City']}" )
    
    response = requests.get(base_url, params=params).json()

    results = response['results']
    
    try:
        print({results[0]['name']})
        hotel_df.loc[index, 'Hotel Name'] = results[0]['name']
        
    except (KeyError, IndexError):
        print("Cannot Find")
# Out:
# The Closest Hotel for Index 70: ponta do sol
# {'Hotel Escarpas do Lago'}
# The Closest Hotel for Index 88: cidreira
# {'Novomar Pousada e Turismo Ltda'}
# The Closest Hotel for Index 138: morondava
# {'La Case Bambou'}
# The Closest Hotel for Index 139: vaini
# {'Dandeli Lake County'}
# The Closest Hotel for Index 176: nador
# {'Hôtel La Giralda'}
# The Closest Hotel for Index 297: mogok
# {'MOGOK HILL HOTEL'}
# The Closest Hotel for Index 444: birjand
# {'تاکسی سرویس آرامش'}

# %%
hotel_df
# Out:
#      City_ID          City  Cloudiness Country        Date  Humidity    Lat  \
# 70        70  ponta do sol           0      BR  1558378767        57 -20.63
# 88        88      cidreira           0      BR  1558378770        66 -30.17
# 138      138     morondava           0      MG  1558378780        69 -20.30
# 139      139         vaini           0      IN  1558378780        88  15.34
# 176      176         nador           0      MA  1558378499        40  35.17
# 297      297         mogok           0      MM  1558378844        51  22.92
# 444      444       birjand           0      IR  1558378880        26  32.86
#
#        Lng  Max Temp  Wind Speed                      Hotel Name
# 70  -46.00     73.68        5.32          Hotel Escarpas do Lago
# 88  -50.22     76.56        5.50  Novomar Pousada e Turismo Ltda
# 138  44.28     79.08        9.06                  La Case Bambou
# 139  74.49     78.90        1.59             Dandeli Lake County
# ...

# %%
# NOTE: Do not change any of the code in this cell

# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
locations = hotel_df[["Lat", "Lng"]]

# %%
# Add marker layer ontop of heat map
markers = gmaps.marker_layer(locations)
fig.add_layer(markers)

# Display Map
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
